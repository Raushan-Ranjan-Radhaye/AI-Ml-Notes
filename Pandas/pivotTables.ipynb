# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    319     31   John  January      Q1
# 1  2023-01-02       B   West    188     47   Mary  January      Q1
# 2  2023-01-03       C  North    288     89    Bob  January      Q1
# 3  2023-01-04       D  South    230     44  Alice  January      Q1
# 4  2023-01-05       A   East    219     18   John  January      Q1
# 5  2023-01-06       B   West    816     36   Mary  January      Q1
# 6  2023-01-07       C  North    340     97    Bob  January      Q1
# 7  2023-01-08       D  South    174     47  Alice  January      Q1
# 8  2023-01-09       A   East    846     80   John  January      Q1
# 9  2023-01-10       B   West    400     90   Mary  January      Q1
# 10 2023-01-11       C  North    378     67    Bob  January      Q1
# 11 2023-01-12       D  South    346     37  Alice  January      Q1
# 12 2023-01-13       A   East    325     68   John  January      Q1
# 13 2023-01-14       B   West    767     83   Mary  January      Q1
# 14 2023-01-15       C  North    752     90    Bob  January      Q1
# 15 2023-01-16       D  South    896     72  Alice  January      Q1
# 16 2023-01-17       A   East    428     37   John  January      Q1
# 17 2023-01-18       B   West    817     55   Mary  January      Q1
# 18 2023-01-19       C  North    148     54    Bob  January      Q1
# 19 2023-01-20       D  South    599     43  Alice  January      Q1

# %%
pd.pivot_table(df, values="Sales", index='Region', columns='Product', aggfunc='median')
##sales ka value ko ham le rahi hai, index me ham region ko banarahi hai  aur columns me ham product ko banarahi hai and sab ka median find ho rahi hai
# Out:
# Product      A      B      C      D
# Region
# East     325.0    NaN    NaN    NaN
# North      NaN    NaN  340.0    NaN
# South      NaN    NaN    NaN  346.0
# West       NaN  767.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=["Sales",'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     427.4    NaN    NaN    NaN  46.8   NaN   NaN   NaN
# North      NaN    NaN  381.2    NaN   NaN   NaN  79.4   NaN
# South      NaN    NaN    NaN  449.0   NaN   NaN   NaN  48.6
# West       NaN  597.6    NaN    NaN   NaN  62.2   NaN   NaN

# %%
##Cross Tabulation
pd.crosstab(df['Product'], df['Region'])
##This is used to counting the values in a give column
# Out:
# Region   East  North  South  West
# Product
# A           5      0      0     0
# B           0      0      0     5
# C           0      5      0     0
# D           0      0      5     0

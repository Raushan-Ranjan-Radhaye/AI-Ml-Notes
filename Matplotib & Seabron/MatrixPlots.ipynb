# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## HeatMap

# %%
flights = sns.load_dataset('flights')
flights

# %%
tips = sns.load_dataset('tips')
tips

# %%
tipscorr = tips[['total_bill', 'tip', 'size']]
tipscorr

# %%
tipscorr.corr()

# %%
sns.heatmap(tipscorr.corr())
plt.show()

# %% [markdown]
# ## Cluster Map

# %%
# sns.clustermap(tipscorr.corr())  # Requires scipy, which is not available in this environment

# %% [markdown]
# ## Pivot Table Heat Map

# %%
pvtflight = flights.pivot_table(index='year', columns='month', values='passengers')
pvtflight

# %%
sns.heatmap(pvtflight)
plt.show()
